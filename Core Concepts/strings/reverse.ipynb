# %% [markdown]
# using reverse without default function
#
# 1. using the loop of the string
# 2. declare the string the above loop
# 3. append the variable like this format loop value + declare string
# 4. return the value

# %%
def reverse(text):
    result = ""
    for i in text:
        result = i + result
    return result
