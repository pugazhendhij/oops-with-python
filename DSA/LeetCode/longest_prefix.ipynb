# %% [markdown]
# 14. Longest Common Prefix
#
# Write a function to find the longest common prefix string amongst an array of strings.
#
# If there is no common prefix, return an empty string "".
#
#
#
# Example 1:
#
# Input: strs = ["flower","flow","flight"]
# Output: "fl"
# Example 2:
#
# Input: strs = ["dog","racecar","car"]
# Output: ""
# Explanation: There is no common prefix among the input strings.

# %%
def longestcommonprefix(strs):
    if not strs:
        return ""
    prefix = strs[0]

    for i in strs[1:]:
        while not i.startswith(prefix):
            prefix = prefix[:-1]
        
        if prefix == "":
            return ""
    
    return prefix

print(longestcommonprefix(["flower","flow","flight"]))
# Out:
# flow
# i flower
# i flowe
# flight
# i flow
# i flo
# fl

# %% [markdown]
# Absolutely, Pugazh — here is a **VERY CLEAR, friendly, step-by-step explanation** of how the **Longest Common Prefix (LCP)** algorithm works, *why* we do every step, and *how* to easily remember it.
#
# I will explain this using simple logic, visuals, and examples.
#
# ---
#
# # 🌼 **PROBLEM IN SIMPLE WORDS**
#
# You're given a list of strings.
#
# Example:
#
# ```
# ["flower", "flow", "flight"]
# ```
#
# Find the **longest part at the beginning** that is common to ALL strings.
#
# Answer = `"fl"`
#
# ---
#
# # 💡 **MAIN IDEA (Very Important)**
#
# ### 👉 Start with the FIRST string as your prefix.
#
# Why?
# Because the longest possible prefix cannot be longer than the first word.
#
# So:
#
# ```
# prefix = "flower"
# ```
#
# Now compare it with every other string.
#
# If they do NOT match, **shrink** the prefix.
#
# ---
#
# # 🧠 **WHY do we shrink the prefix?**
#
# If `"flower"` doesn't match `"flow"`,
# that means `"flower"` is TOO BIG.
#
# So we reduce it from the end:
#
# ```
# flower → flowe → flow
# ```
#
# Now `"flow"` matches `"flow"` (second word).
# Good! Continue.
#
# Next compare `"flow"` with `"flight"`:
#
# ```
# flight does NOT start with "flow"
# Shrink again:
# flow → flo → fl
# ```
#
# Now `"flight"` starts with `"fl"` → match!
# This is the final longest common prefix.
#
# ---
#
# # 🎯 **FULL ALGORITHM EXPLAINED CLEARLY**
#
# ### STEP 1 — Take first string as prefix
#
# ```
# prefix = strs[0]
# ```
#
# This is the maximum prefix possible.
#
# ---
#
# ### STEP 2 — Compare prefix with each next string
#
# For each string:
#
# ```
# while that string DOES NOT start with prefix:
#     remove the last character from prefix
# ```
#
# This shrinking ensures prefix always stays a **true common prefix** for all previous words.
#
# ---
#
# ### STEP 3 — If prefix becomes empty → return ""
#
# Because no common prefix exists.
#
# ---
#
# ### STEP 4 — After checking all strings → return prefix
#
# ---
#
# # 🔍 **DETAILED EXAMPLE (Very Slow & Clear)**
#
# Input:
#
# ```
# ["flower", "flow", "flight"]
# ```
#
# ### 1️⃣ prefix = "flower"
#
# ---
#
# ### Compare with "flow"
#
# Does "flow" start with "flower"?
# → ❌ No
#
# Shrink prefix:
#
# ```
# flower → flowe
# ```
#
# Does "flow" start with "flowe"?
# → ❌ No
#
# Shrink again:
#
# ```
# flowe → flow
# ```
#
# Does "flow" start with "flow"?
# → ✔ Yes
#
# Good! Keep `"flow"`.
#
# ---
#
# ### Compare prefix "flow" with "flight"
#
# Does "flight" start with "flow"?
# → ❌ No
#
# Shrink prefix:
#
# ```
# flow → flo
# ```
#
# Does "flight" start with "flo"?
# → ❌ No
#
# Shrink:
#
# ```
# flo → fl
# ```
#
# Does "flight" start with "fl"?
# → ✔ Yes
#
# Stop.
#
# Final answer = `"fl"`.
#
# ---
#
# # 🧠 MEMORY TRICK (VERY USEFUL)
#
# Think of “prefix” as a **rubber band**.
#
# * Start long
# * Compare with next string
# * If the band doesn’t fit → shrink
# * Continue until it fits all strings
#
# When it fits all → THAT is the longest common prefix.
#
# ---
#
# # 📦 **TIME COMPLEXITY EXPLANATION (Easy)**
#
# * You may shrink prefix up to **m** times (m = length of shortest string)
# * You do this for **n strings**
#
# Thus:
#
# ```
# Time = O(n × m)
# ```
#
# Example: ["flower", "flow", "flight"]
#
# * n = 3
# * m = 2 (from "fl" in "flight")
#
# Space = O(1) → no extra memory used.
#
# ---
