# %% [markdown]
# 136. Single Number
#
#    -  Given a non-empty array of integers nums, every element appears twice except for one. Find that single one.
#
#    -  You must implement a solution with a linear runtime complexity and use only constant extra space.
#
#
#   - Example 1:
#     Input: nums = [2,2,1]
#     Output: 1
#
#   - Example 2:
#     Input: nums = [4,1,2,1,2]
#     Output: 4
#
# -  Example 3:
#     Input: nums = [1]
#     Output: 1

# %%
arr = [2, 3, 2, 4, 4]

xor_all = 0
for x in arr:
    xor_all ^= x

print(xor_all)
# Out:
# 3

# %% [markdown]
# XOR rule:
#
# ```
# A ^ A = 0     (same numbers cancel out)
# A ^ 0 = A
# ```
#
# Now apply step-by-step:
#
# ### Start:
#
# ```
# xor_all = 0
# ```
#
# ### Step through array:
#
# 1️⃣ `0 ^ 2 = 2`
# 2️⃣ `2 ^ 3 = 1`
# 3️⃣ `1 ^ 2 = 3`
# 4️⃣ `3 ^ 4 = 7`
# 5️⃣ `7 ^ 4 = 3`
#
# Final answer:
#
# ```
# 3
# ```
#
# ---
#
# # 🎉 WHY does only **3** remain?
#
# Because pairs cancel out:
#
# ```
# 2 ^ 2 = 0
# 4 ^ 4 = 0
# ```
#
# So the array becomes:
#
# ```
# 0 ^ 3 ^ 0 = 3
# ```
