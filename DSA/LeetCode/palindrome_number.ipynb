# %% [markdown]
# 9. Palindrome Number
#
#     Given an integer x, return true if x is a palindrome, and false otherwise.
#
#
#
#     Example 1:
#
#     Input: x = 121
#     Output: true
#     Explanation: 121 reads as 121 from left to right and from right to left.
#     Example 2:
#
#     Input: x = -121
#     Output: false
#     Explanation: From left to right, it reads -121. From right to left, it becomes 121-. Therefore it is not a palindrome.
#     Example 3:
#
#     Input: x = 10
#     Output: false
#     Explanation: Reads 01 from right to left. Therefore it is not a palindrome.

# %%
def palindrome_number(n):
    temp = n
    rev = 0
    if n < 0:
        return False

    while temp > 0:
        last = temp % 10
        rev = (rev * 10) + last
        temp //= 10
        
    return n == rev

print(palindrome_number(121))
print(palindrome_number(-121))
print(palindrome_number(10))
# Out:
# True
# False
# False

# %% [markdown]
# # ✅ **STEP-BY-STEP APPROACH (Easy to Remember)**
#
# ### **Step 1 → Check negative numbers**
#
# A negative number is NEVER a palindrome because of the minus sign.
#
# ```
# if n < 0: return False
# ```
#
# ---
#
# ### **Step 2 → Copy the number**
#
# You need a temporary variable to modify:
#
# ```
# temp = n
# ```
#
# ---
#
# ### **Step 3 → Reverse the digits**
#
# Use a loop:
#
# 1. Take last digit
#    `last = temp % 10`
#
# 2. Add it to reversed number
#    `rev = rev * 10 + last`
#
# 3. Remove last digit
#    `temp //= 10`
#
# ---
#
# ### **Step 4 → Compare original vs reversed**
#
# If both are equal → palindrome
# else → not palindrome
#
# ```
# return n == rev
# ```
